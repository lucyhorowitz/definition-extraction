# %%
import json

nlab = json.loads(open("/Users/lucyhorowitz/Documents/spaCy-Obsidian project/nlab/nlab_pages.json","r").read())
text = open("/Users/lucyhorowitz/Documents/GitHub/definition-extraction/textbooks/nlab/nlab_mathgloss.txt","a")

for line in open("/Users/lucyhorowitz/Documents/spaCy-Obsidian project/wikidata/to_neo4j2.csv","r").readlines():
    page = line.split(',')[-1].strip()
    for entry in nlab:
        if entry["url"].replace("source","show") == page:
            print("page")
            text.write(entry["source"] + "\n")
# Out:
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# page
# ...
